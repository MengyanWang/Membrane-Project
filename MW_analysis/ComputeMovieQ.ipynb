# %%
import sys
from VectorAlgebra import *
from Bio.PDB.PDBParser import PDBParser

# %%
sys.argv[1] = "1r69.pdb"
sys.argv[2] = "movie.pdb"

# %%
struct_id = sys.argv[1]
struct_id2 = sys.argv[2]

pdb_file = sys.argv[1]
pdb_file2 = sys.argv[2]

# %%
p = PDBParser(PERMISSIVE=1)

# %%
sigma = []
sigma_sq = []
sigma_exp = 0.15

for i in range (0,len(ca_atoms_pdb)+1):
    sigma.append((1+i)**sigma_exp)
    sigma_sq.append(sigma[-1]*sigma[-1])
    
def computeQ():
    Q = {}
    norm = {}
    N = len(ca_atoms_pdb)
    for ia in range(0,N):
        for ja in range(ia+3,N):
            r = vabs(vector(ca_atoms_pdb[ia], ca_atoms_pdb[ja]))
            rn = vabs(vector(ca_atoms_pdb2[ia], ca_atoms_pdb2[ja]))
            dr = r - rn
            index = 1
            if not index in Q:
                Q[index] = 0.0
                norm[index] = 0
            Q[index] = Q[index] + exp(-dr*dr/(2*sigma_sq[ja-ia]))
            norm[index] = norm[index] + 1
    for key in Q:
        Q[key]=Q[key]/norm[key]
    return Q

# %%
s = p.get_structure(struct_id, pdb_file)
# print(s)
ca_atoms_pdb = []
pdb_chain_id = []

chains = s[0].get_list()
ichain = 0
for chain in chains:
    ichain = ichain + 1
    for res in chain:
        is_regular_res = res.has_id('CA') and res.has_id('O')
        res_id = res.get_id()[0]
#         print(res_id)
        if (res_id==' ' or res_id=='H_MSE' or res_id=='H_M3L' or res_id=='H_CAS') and is_regular_res:
            ca_atoms_pdb.append(res['CA'].get_coord())
            pdb_chain_id.append(ichain)
#             print(len(ca_atoms_pdb2))
# Out:
# /home/mw88/miniconda3/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1001
#   warnings.warn(

# %%
s2 = p.get_structure(struct_id2, pdb_file2)

for model in s2:
#     print(f'Calculating Q value for frame {i}')
    ca_atoms_pdb2 = []
    pdb_chain_id2 = []
    
    chains = model.get_list()

    ichain = 0
    for chain in chains:
        ichain = ichain + 1
        for res in chain:
            is_regular_res = res.has_id('CA') and res.has_id('O')
            res_id = res.get_id()[0]
#             print(res_id)
            # if (res_id==' ' or res_id=='H_MSE' or res_id=='H_M3L' or res_id=='H_CAS' or res_id=='H_NGP' or res_id=='H_IGL') and is_regular_res:
#             if is_regular_res:
#                 print(len(res))
            ca_atoms_pdb2.append(res['CA'].get_coord())
            pdb_chain_id2.append(ichain)
#             print(len(ca_atoms_pdb2))
    q = computeQ()
    print(q)
# Out:
# /home/mw88/miniconda3/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line
# {1: 0.45862240602428805}
# {1: 0.40292803534227883}
# {1: 0.42756322938253993}
# {1: 0.42499600141215704}
# {1: 0.3963950399903418}
# {1: 0.4533187967710875}
# {1: 0.43190143577617746}
# {1: 0.4118972553689786}
# {1: 0.44932261076900226}
# {1: 0.45301668342409757}
# {1: 0.4463779612824449}
# {1: 0.42604958368119}
# {1: 0.46424950225613937}
# {1: 0.3906477538091523}
# {1: 0.4423816887819069}
# {1: 0.3996656399672085}
# {1: 0.4176297040024794}
# {1: 0.45675939154270273}
# {1: 0.3829079433296644}
# {1: 0.42232079018164914}
# {1: 0.40267976149969037}
# {1: 0.4561210525811726}
# {1: 0.4192561576293398}
# {1: 0.42778862566321574}
# {1: 0.42621145791618387}
# {1: 0.46342458700843947}
# {1: 0.44182326475792255}
# {1: 0.41693245987507926}
# {1: 0.4184064701295115}
# {1: 0.40576005206037963}
# {1: 0.4234874459668672}
# {1: 0.4419462630851634}
# {1: 0.42047945108239854}
# {1: 0.4870202495371667}
# {1: 0.4669354834687719}
# {1: 0.4318109738452828}
# {1: 0.46916879164932973}
# {1: 0.4597057696266894}
# {1: 0.4366623273069528}
# {1: 0.4457866447709714}
# {1: 0.4686628775063673}
# {1: 0.42864251215806853}
# {1: 0.4318658149572093}
# {1: 0.46915673265663915}
# {1: 0.4447901924108574}
# {1: 0.396775173366003}
# {1: 0.4455766076758114}
# {1: 0.4228730626348207}
# {1: 0.44286206111798204}
# {1: 0.4611741500501609}
# {1: 0.4031423941261461}
# {1: 0.47682743489227675}
# {1: 0.4285130277870037}
# {1: 0.4242251824913514}
# {1: 0.4400639375774415}
# {1: 0.43734501763579886}
# {1: 0.43829691021381345}
# {1: 0.4254976188768172}
# {1: 0.41878476217644706}
# {1: 0.4054453083841885}
# {1: 0.3785237429122304}
# {1: 0.43848022812179277}
# {1: 0.43880866770080496}
# {1: 0.40205928042394534}
# {1: 0.4594516195352005}
# {1: 0.4637897610191494}
# {1: 0.4230926947911777}
# {1: 0.39450373857371673}
# {1: 0.43125463799350805}
# {1: 0.4625349594838004}
# {1: 0.3961390693654144}
# {1: 0.4467215233859874}
# {1: 0.4401390900883138}
# {1: 0.4025339467394626}
# {1: 0.4487080231077908}
# {1: 0.44270971662855974}
# {1: 0.42478990869365146}
# {1: 0.422990832751897}
# {1: 0.42495586518088857}
# {1: 0.46346278473099767}
# {1: 0.4053242943336281}
# {1: 0.40690052842899094}
# {1: 0.46865226696057416}
# {1: 0.43174783885334533}
# {1: 0.4510273951577908}
# {1: 0.4860061343740003}
# {1: 0.4915663138773269}
# {1: 0.4270017645787391}
# {1: 0.43619091395099713}
# {1: 0.4507931722626085}
# {1: 0.44598331918348333}
# {1: 0.4399050627969266}
# {1: 0.45170338216514816}
# {1: 0.46144555277360955}
# {1: 0.44941075161698407}
# {1: 0.3749464452758451}
# {1: 0.43174952818574974}
# {1: 0.43838724437892024}
# {1: 0.3937951197949738}
# {1: 0.4049289001350248}
# {1: 0.46442366934409784}
# {1: 0.47458784921287506}
# {1: 0.4809934028320433}
# {1: 0.4320976628027399}
# {1: 0.4509708157867544}
# {1: 0.45145190775714167}
# {1: 0.4688049926896578}
# {1: 0.4516488209059161}
# {1: 0.4484460892785099}
# {1: 0.42407907435576664}
# {1: 0.43398288196825413}
# {1: 0.4371856444308164}
# {1: 0.4351864868471564}
# {1: 0.4428800356318495}
# {1: 0.43616193083628374}
# {1: 0.48235507621411683}
# {1: 0.4650806153881159}
# {1: 0.45049290874900194}
# {1: 0.44746523842336805}
# {1: 0.4429259005080895}
# {1: 0.39229721617627106}
# {1: 0.4548085611368313}
# {1: 0.4463840761232122}
# {1: 0.4413618350660479}
# {1: 0.4344495485435886}
# {1: 0.4268770715638996}
# {1: 0.40120172535325727}
# {1: 0.48039542049817857}
# {1: 0.4345598503464697}
# {1: 0.435056207071116}
# {1: 0.42840719793779974}
# {1: 0.41855336255652487}
# {1: 0.4260893773129679}
# {1: 0.44992692024949416}
# {1: 0.46854674276370156}
# {1: 0.42264821523028}
# {1: 0.4203267980855071}
# {1: 0.44199482972273657}
# {1: 0.46819199631409975}
# {1: 0.40010827444383557}
# {1: 0.4631245357660507}
# {1: 0.4776432385586692}
# {1: 0.45576837651825625}
# {1: 0.4248238723682393}
# {1: 0.42676341748763263}
# {1: 0.4354562445101508}
# {1: 0.38493005002578695}
# {1: 0.4018847102914853}
# {1: 0.4601918185010726}
# {1: 0.45376069505836575}
# {1: 0.4278174123125734}
# {1: 0.4423250444227309}
# {1: 0.4552107505587585}
# {1: 0.41975257622006884}
# {1: 0.47175205068198256}
# {1: 0.44934344385674635}
# {1: 0.4202045571684988}
# {1: 0.43031979161989536}
# {1: 0.41094186527170795}
# {1: 0.441742399513751}
# {1: 0.4500693933028846}
# {1: 0.42354089878265677}
# {1: 0.4381316156099637}
# {1: 0.4370180172279915}
# {1: 0.4057915411326446}
# {1: 0.47552978341744245}
# {1: 0.5088941775284703}
# {1: 0.4656811090684555}
# {1: 0.4759161330562986}
# {1: 0.45852762592889235}
# {1: 0.4619207056148116}
# {1: 0.4278543084646442}
# {1: 0.47836816052840125}
# {1: 0.4863122154530224}
# {1: 0.4364068234018796}
# {1: 0.4198272242395671}
# {1: 0.46281377750234176}
# {1: 0.4776079411146114}
# {1: 0.4353523081734738}
# {1: 0.45058101797474126}
# {1: 0.43279624638853953}
# {1: 0.43687553966527676}
# {1: 0.44972959579918637}
# {1: 0.47498129658103255}
# {1: 0.4490915357094122}
# {1: 0.4018264908450946}
# {1: 0.47036502392061386}
# {1: 0.43654740105965256}
# {1: 0.44296671972122026}
# {1: 0.40381663456262623}
# {1: 0.41178736966645096}
# {1: 0.42680535363633476}
# {1: 0.41658929075804413}
# {1: 0.4654748442846188}
